# %%
import a8c_styling
import seaborn as sns
from matplotlib import pylab as plt

plt.figure()
a8c_styling.sinplot(4) #this is how a default plot looks like


plt.figure()
a8c_styling.sinplot(4)
plt.ylabel('this is Y', 
           **a8c_styling.ylabelparams) #horizontal label for 
                                    #more readability
    
a8c_styling.fewer_axis_ticks() # we don't want that many ticks
sns.despine()

# %%
a8c_styling.a8c_style

# %%
gca().get_xlim()
# Out:
# (0.0, 1.0)

# %%
import random
styles = ["a8c_default", "a8c_white", "a8c_whitegrid", "a8c_dark", "a8c_darkgrid", "a8c_ticks"]
#random.shuffle(styles)
for s in styles:
    plt.figure()
    style = a8c_styling.a8c_axes_style(s)
    sns.set_style(style)
    fig = a8c_styling.sinplot(3, -1)
    if 'dark' in s:
        fig.set_facecolor(a8c_colors.a8c_gray_dark)
    title(s)
    sns.despine()

# %%
a8c_styling.sinplot(3, -1)

# %%
sns.set_style(a8c_styling.a8c_style)
a8c_styling.sinplot()
sns.despine()
